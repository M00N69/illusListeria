# %% [markdown]
# <a href="https://colab.research.google.com/github/M00N69/illusListeria/blob/main/PROJETSTATEMP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install streamlit gspread oauth2client
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 30.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 28.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 67.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 10.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 9.8 MB/s eta 0:00:00
# ...

# %%
from google.colab import files

uploaded = files.upload()

for filename in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=filename, length=len(uploaded[filename])))
# Out:
#      <input type="file" id="files-a8b51cb2-2ec1-41ad-9e9b-55692b2ef7f5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a8b51cb2-2ec1-41ad-9e9b-55692b2ef7f5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import gspread
from oauth2client.service_account import ServiceAccountCredentials

# Après avoir téléchargé le fichier, utilisez le nom du fichier JSON directement
path_to_creds = '/content/projetstatemp-854578eeba46.json'

# Définissez la portée
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

# Chargez les credentials à partir du fichier
credentials = ServiceAccountCredentials.from_json_keyfile_name(path_to_creds, scope)

# Autorisez l'accès à gspread avec ces credentials
gc = gspread.authorize(credentials)

# Essayez d'ouvrir la feuille de calcul par son titre
spreadsheet_title = 'PROJETSTATEMP'  # Remplacez par le titre de votre feuille de calcul
try:
    worksheet = gc.open(spreadsheet_title).sheet1
    # Lisez les données de la première ligne
    first_row = worksheet.row_values(1)
    print("Première ligne de la feuille de calcul : ", first_row)
except Exception as e:
    print("Il y a eu une erreur : ", e)
# Out:
# Première ligne de la feuille de calcul :  ['UserID', 'UserName', 'PasswordHash', 'Email', 'DateCreated', 'LastLogin', 'AnalysisData', 'AnalysisResults']

# %% [markdown]
# Parfait, pour continuer le projet, vous pouvez procéder comme suit :
#
# ### Étape 1 : Structuration de l'Application
#
# Organisez votre code source en différents modules pour une meilleure maintenance et évolutivité. Par exemple :
#
# - `auth.py` : pour la gestion de l'authentification des utilisateurs.
# - `sheets.py` : pour toutes les interactions avec Google Sheets.
# - `analysis.py` : pour exécuter les analyses statistiques.
# - `app.py` : fichier principal de l'application Streamlit.
#
# ### Étape 2 : Gestion de l'Authentification
#
# Dans `auth.py`, implémentez les fonctionnalités suivantes :
#
# - Inscription de l'utilisateur.
# - Hachage des mots de passe.
# - Connexion de l'utilisateur.
# - Gestion des sessions utilisateurs.
#
# Pour le hachage des mots de passe, utilisez une bibliothèque éprouvée comme `bcrypt`.
#
# ### Étape 3 : Interaction avec Google Sheets
#
# Dans `sheets.py`, créez des fonctions pour :
#
# - Ajouter un nouvel utilisateur à la feuille de calcul.
# - Mettre à jour les informations de l'utilisateur.
# - Récupérer les données pour l'analyse.
# - Écrire les résultats de l'analyse dans la feuille de calcul.
#
# Utilisez `gspread` pour interagir avec la feuille de calcul.
#
# ### Étape 4 : Fonctionnalités d'Analyse Statistique
#
# Dans `analysis.py`, définissez des fonctions pour :
#
# - Effectuer des calculs statistiques de base.
# - Générer des intervalles de confiance.
# - Réaliser des tests d'hypothèses.
# - Produire des visualisations des données.
#
# Utilisez des bibliothèques comme `numpy`, `scipy`, et `matplotlib` ou `seaborn` pour les calculs et les visualisations.
#
# ### Étape 5 : Développement de l'Application Streamlit
#
# Dans `app.py`, utilisez Streamlit pour :
#
# - Créer l'interface utilisateur.
# - Gérer la navigation entre les différentes sections de l'application.
# - Afficher les formulaires pour la saisie des données par l'utilisateur.
# - Présenter les résultats des analyses.
#
# ### Étape 6 : Test et Débogage
#
# Testez chaque fonctionnalité individuellement, puis l'application dans son ensemble pour vous assurer que tout fonctionne comme prévu.
#
# ### Étape 7 : Documentation
#
# Documentez chaque fonction et module avec des docstrings, et créez un fichier README.md pour votre dépôt GitHub qui explique comment utiliser l'application.
#
# ### Étape 8 : Déploiement
#
# Une fois que tout fonctionne correctement en local, préparez votre application pour le déploiement :
#
# - Configurez un dépôt GitHub pour votre projet.
# - Utilisez GitHub Actions pour l'intégration continue/déploiement continu (CI/CD) si nécessaire.
# - Déployez l'application sur une plateforme de déploiement telle que Heroku, AWS, ou un service similaire.
#
# ### Étape 9 : Maintenance et Évolutions
#
# - Surveillez le fonctionnement de votre application.
# - Recueillez les retours des utilisateurs.
# - Mettez régulièrement à jour votre application pour corriger les bugs et ajouter de nouvelles fonctionnalités.
#
# Pour commencer, vous pouvez créer le fichier `app.py` et y configurer l'application Streamlit de base. Ensuite, vous pourrez progressivement ajouter les autres modules et fonctionnalités.
#
# Si vous avez besoin d'aide sur des aspects spécifiques du développement, n'hésitez pas à demander des précisions ou des exemples de code.

# %%
# !pip install streamlit
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 26.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 20.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 55.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.0/83.0 kB 9.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.0 MB/s eta 0:00:00
# ...

# %%
# !pip install bcrypt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 698.9/698.9 kB 3.9 MB/s eta 0:00:00
# ...

# %%
# app.py (fichier principal de l'application Streamlit)

import streamlit as st
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from bcrypt import hashpw, gensalt
import pandas as pd

# Initialisation de la connexion à Google Sheets
scope = ['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('/content/projetstatemp-854578eeba46.json', scope)
client = gspread.authorize(creds)
sheet = client.open('PROJETSTATEMP').sheet1

def main():
    st.title("Outil d'Analyse Statistique pour la Sécurité Alimentaire")

    # Explication du contexte de l'outil
    if st.sidebar.checkbox("Contexte de l'outil"):
        st.subheader("À propos de cet outil")
        st.write("Explication détaillée du contexte et de l'utilisation de l'outil...")

    # Menu de navigation
    menu = ["Accueil", "Créer un compte", "Se connecter"]
    choice = st.sidebar.selectbox("Menu", menu)

    if choice == "Accueil":
        st.subheader("Bienvenue dans l'Outil d'Analyse Statistique pour la Sécurité Alimentaire")
        # Autres éléments de l'UI pour l'Accueil
    elif choice == "Créer un compte":
        st.subheader("Créer un Nouveau Compte")
        new_username = st.text_input("Nom d'utilisateur")
        new_password = st.text_input("Mot de passe", type='password')
        new_email = st.text_input("Email")
        if st.button("S'inscrire"):
            create_account(new_username, new_password, new_email)
    elif choice == "Se connecter":
        st.subheader("Page de Connexion")
        username = st.text_input("Nom d'utilisateur")
        password = st.text_input("Mot de passe", type='password')
        if st.button("Se connecter"):
            login_user(username, password)

    # Importation de données pour l'analyse
    st.subheader("Importer des Données pour l'Analyse")
    uploaded_file = st.file_uploader("Choisissez un fichier CSV", type='csv')
    if uploaded_file is not None:
        data = pd.read_csv(uploaded_file)
        st.write(data)  # Affiche le dataframe dans l'interface utilisateur
        # Plus de logique pour traiter et stocker les données importées

def create_account(username, password, email):
    # Cette fonction crée un compte dans Google Sheets
    # Vous devez implémenter la logique de création de compte ici
    pass

def login_user(username, password):
    # Cette fonction authentifie un utilisateur
    # Vous devez implémenter la logique d'authentification ici
    pass

if __name__ == '__main__':
    main()
# Out:
# 2024-02-20 19:41:07.699
# ...
#   command:
#
#     streamlit run /usr/local/lib/python3.10/dist-packages/colab_kernel_launcher.py [ARGUMENTS]
